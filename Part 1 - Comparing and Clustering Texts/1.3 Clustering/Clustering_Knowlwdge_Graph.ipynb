# %%
import os
import pandas as pd
import numpy as np
from collections import Counter
from urllib.parse import urlparse
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.model_selection import train_test_split
import matplotlib.pyplot as plt

# %%
physics_and_chemistry_nobel_laureate = pd.read_csv(r"..\..\Web Scraped Corpus\physics_and_chemistry_nobel_laureate.csv")

# Fetch Corresponding Knowledge Graph json file for each laureate using their name
def retrieve_knowlege_graph(name_category):
    # Remove all white spaces from the name
    name = name_category['name'].replace(" ", "__")
    category = name_category['category'].lower()
    # Load the knowledge graph json file
    try:
        json = pd.read_json(os.path.join(f"{category}_nobel_laureate", f"{name}.json"))
        return json
    except Exception as e:
        print(f"File {name}.json not found", e)

# Retrieve the knowledge graph for each laureate
physics_and_chemistry_nobel_laureate['knowledge_graph'] = physics_and_chemistry_nobel_laureate[[ 'name', 'category']].apply(retrieve_knowlege_graph, axis=1)

# %%
knowledge_graph = pd.concat(physics_and_chemistry_nobel_laureate['knowledge_graph'].tolist(), ignore_index=True)


def get_last_part(payload):
    parsed_url = urlparse(payload['value'])
    path = parsed_url.path
    parts = path.split('/')
    last_part = [part for part in parts if part][-1]  # This gets the last non-empty part
    return last_part

objects = knowledge_graph['object'].apply(get_last_part).tolist()

objects
# Out:
# ['American_Roentgen_Ray_Society',
#  'Ampere',
#  'Electric_charge',
#  'National_Council_on_Radiation_Protection_and_Measurements',
#  'William_Valentine_Mayneord',
#  'Becquerel',
#  'United_States',
#  'Volume',
#  'Dosimetry',
#  'International_Commission_on_Radiation_Units_and_Measurements',
#  'International_Commission_on_Radiological_Protection',
#  'International_Congress_of_Radiology',
#  'Second',
#  'Mass',
#  'Medical_imaging',
#  'SI_base_unit',
#  'Quartz_fiber_dosimeter',
#  'Gamma_ray',
#  'General_Conference_on_Weights_and_Measures',
#  'Germany',
#  'Equivalent_dose',
#  'Louis_Harold_Gray',
#  'Statcoulomb',
#  '°C',
#  'Kerma_(physics)',
#  'USSR',
#  'Wilhelm_Röntgen',
#  'Cubic_centimetre',
#  'Curie_(unit)',
#  'European_Economic_Community',
#  'Category:Units_of_radiation_dose',
#  'Centimetre–gram–second_system_of_units',
#  'Gray_(unit)',
#  'Radiation_exposure',
#  'Rad_(unit)',
#  'Radiation',
#  'Roentgen_equivalent_man',
#  'International_System_of_Units',
#  'Ionising_radiation',
#  'Category:Non-SI_metric_units',
#  'Absorbed_dose',
#  'Kilogram',
#  'Effective_dose_(radiation)',
#  'International_Committee_for_Weights_and_Measures',
#  'National_Institute_of_Standards_and_Technology',
#  'Orders_of_magnitude_(radiation)',
#  'Radiation_protection',
#  'X-ray',
#  'Sievert',
#  'European_units_of_measurement_directives',
#  'Roentgen_equivalent_physical',
#  'International_X-ray_and_Radium_Protection_Committee',
#  'Ion_chamber',
#  'Villard_unit',
#  'Cgs_system',
#  'Human_tissue',
#  'Rem_(unit)',
#  'All-union_committee_of_standards',
#  'Standard_pressure',
#  'File:Dose_quantities_and_units.png',
#  'File:Dosimeter_ablesung.jpg',
#  'Category:Synthetic_elements',
#  'Base_(chemistry)',
#  'Bismuth-209',
#  'Hydrogen',
#  'Hydrogen_sulfide',
#  'Periodic_table',
#  'Livermorium',
#  'Osmium',
#  'Radon',
#  'Copernicium',
#  'Meitnerium',
#  "Mendeleev's_predicted_elements",
#  'Chemical_element',
#  'Noble_gas',
#  'Electron_affinity',
#  'Electron_capture',
#  'Electron_shell',
#  'Germany',
#  'Gold',
#  'Gold_heptafluoride',
#  'Moscovium',
#  'Congener_(chemistry)',
#  'Coordination_complex',
#  'Copper',
#  'The_Periodic_Table_of_Videos',
#  'Category:Roentgenium',
#  'Transition_metals',
#  'Sigurd_Hofmann',
#  'Silver',
#  'Density',
#  'Ö',
#  'Body-centered_cubic',
#  'Placeholder_name',
#  'Synthetic_element',
#  'Transition_metal',
#  'Bromine',
#  'Category:Chemical_elements',
#  'Transactinide_element',
#  'Wilhelm_Röntgen',
#  'Edward_Norton',
#  'Ludvig_Lorenz',
#  'Eduard_Lorenz',
#  'Hendrik_Lorentz',
#  'Carl_David_Anderson',
#  'Carolyn_Porco',
#  'Carver_Mead',
#  'Cassini–Huygens',
#  'American_lower_class',
#  'American_middle_class',
#  'Amos_G._Throop',
#  'Category:Technological_universities_in_the_United_States',
#  'QS_World_University_Rankings',
#  'Qian_Xuesen',
#  'Quantum_Hoops',
#  'Quantum_chemistry',
#  'Quantum_electrodynamics',
#  'Quantum_mechanics',
#  'Quark',
#  'Rockefeller_University',
#  'Rocket',
#  'Rose_Bowl_(stadium)',
#  'Rose_Bowl_Game',
#  'Royal_Swedish_Academy_of_Sciences',
#  'San_Diego_County,_California',
#  'San_Fernando,_California',
#  'Engineering_education',
#  'Nobel_Prize_in_Chemistry',
#  'Transuranium_element',
#  'Project_Vista',
#  'Barry_Simon',
#  'Bell_Labs',
#  'Benoit_Mandelbrot',
#  'Berkshire_Hathaway',
#  'Bertram_Goodhue',
#  'Beverly_Hills_Cop_(film_series)',
#  'Biology',
#  'Bishop,_California',
#  'David_Baltimore',
#  'Category:Science_and_technology_in_Greater_Los_Angeles',
#  'Category:Universities_and_colleges_in_Los_Angeles_County,_California',
#  'Aperture_Science',
#  'Hollywood_Sign',
#  'Homework',
#  'Hotmail',
#  'House_System_at_the_California_Institute_of_Technology',
#  'Howard_Hughes_Medical_Institute',
#  'Hulk',
#  'List_of_Nobel_laureates_affiliated_with_California_Institute_of_Technology',
#  'Arnold_Orville_Beckman',
#  'Paul_Dirac',
#  'PayScale',
#  'Regina_E._Dugan',
#  'Richard_Feynman',
#  'Richland,_Washington',
#  'Ride_of_the_Valkyries',
#  'Robert_Andrews_Millikan',
#  'Robert_F._Christy',
#  'Under_Secretary_of_Energy_for_Science',
#  'United_States_Department_of_Defense',
#  'United_States_Department_of_Energy',
#  'United_States_Department_of_Health_and_Human_Services',
#  'United_States_National_Research_Council',
#  'United_States_Navy',
#  'United_States_Secretary_of_Defense',
#  'United_States_Senate',
#  'Universities_Research_Association',
#  'University_of_California',
#  'University_of_Chicago',
#  'University_of_Southern_California',
#  'Vernon_L._Smith',
#  'Vortices',
#  'Infinite_Corridor',
#  'Infrared_Processing_and_Analysis_Center',
#  'Mandelbrot_set',
#  'Wolfram_Alpha',
#  'James_D._Watson',
#  'Pell_grant',
#  'Compaq',
#  'Cosmology',
#  'Coursera',
#  'Crafoord_Prize',
#  'Analysis_of_algorithms',
#  'Mason_Porter',
#  'Massachusetts_Institute_of_Technology',
#  'Massive_open_online_course',
#  'MathWorks',
#  'Mathematica',
#  'Matlab',
#  'Mauna_Kea_Observatory',
#  'Menthol',
#  'SAT',
#  'STEM_fields',
#  'Chemical_biology',
#  'Narendra_Karmarkar',
#  'Nathan_Lewis_(chemist)',
#  'National_Medal_of_Science',
#  'Old_Town_Pasadena',
#  'Student_prank',
#  'Clair_Patterson',
#  'Cambridge_University_Library',
#  'Cambridge_University_Press',
#  'Roger_Penrose',
#  'Scientific_journal',
#  'Nobel_Prize_in_Chemistry',
#  'John_Stevens_Henslow',
#  'John_William_Strutt,_3rd_Baron_Rayleigh',
#  'Joseph_Larmor',
#  'Paul_Dirac',
#  'University_of_Cambridge',
#  'Category:Clubs_and_societies_of_the_University_of_Cambridge',
#  'On_the_Origin_of_Species',
#  "Christ's_College,_Cambridge",
#  'Edward_Daniel_Clarke',
#  'Geological_Society_of_London',
#  'Antony_Hewish',
#  'Category:Philosophical_societies_in_the_United_Kingdom',
#  'Cambridge_University_Moral_Sciences_Club',
#  'Category:Organizations_established_in_1819',
#  'Stephen_Hawking',
#  'Fellow',
#  'Mathematical_Proceedings_of_the_Cambridge_Philosophical_Society',
#  'Adam_Sedgwick',
#  'Alan_Turing',
#  'Category:Scientific_societies_based_in_the_United_Kingdom',
#  'Ernest_Rutherford',
#  'Francis_Crick',
#  'Nobel_Prize',
#  'Nobel_Prize_in_Physics',
#  'HMS_Beagle',
#  'Hendrik_Lorentz',
#  'J._J._Thomson',
#  'James_Francis_Stephens',
#  'Category:1819_establishments_in_England',
#  'Charles_Babbage',
#  'Charles_Darwin',
#  'King_William_IV',
#  'Law',
#  'Lawrence_Bragg',
#  'Dorothy_Hodgkin',
#  'Marie_Curie',
#  'Martin_Rees',
#  'Philosophy',
#  'Pieter_Zeeman',
#  'Second_voyage_of_HMS_Beagle',
#  'Medicine',
#  'Extracts_from_Letters_to_Henslow',
#  'Theology',
#  'File:Stephen_Hawking.StarChild.jpg',
#  'File:Cambridge-philosophical-society-blue-plaque.jpg',
#  'File:Extracts_from_letters_to_Henslow.jpeg',
#  'File:On-the-fishes-of-madeira.jpg',
#  'Capelle',
#  'Provinces_of_the_Netherlands',
#  'Scharendijke',
#  'North_Beveland',
#  'Democraten_66',
#  'Deputy_Prime_Minister_of_the_Netherlands',
#  'Hugo_de_Jonge',
#  'Joost_Berman',
#  'List_of_municipalities_of_the_Netherlands',
#  'List_of_sovereign_states',
#  'Petrus_Peckius_the_Elder',
#  'Renesse',
#  'Volkspartij_voor_Vrijheid_en_Democratie',
#  'Category:Islands_of_the_Rhine–Meuse–Scheldt_delta',
#  'Duiveland',
#  'Johannes_Cornelis_de_Jonge',
#  'Johannes_van_de_Velde_Olivier',
#  'Levinus_Lemnius',
#  'Postal_codes_in_the_Netherlands',
#  'Zierikzeesche_Nieuwsbode',
#  'Common_redshank',
#  'Rutger_Bregman',
#  'Ester_Naomi_Perquin',
#  'Oosterschelde',
#  'ChristenUnie',
#  'Elkerzee',
#  'Ellemeet',
#  'Goedereede',
#  'Goeree-Overflakkee',
#  'Moriaanshoofd',
#  'Municipalities_of_the_Netherlands',
#  'Cornelius_van_Zierikzee',
#  'Tholen',
#  'Dam',
#  'Anton_Constandse',
#  'Category:Rhine–Meuse–Scheldt_delta',
#  'Leen_van_Dijke',
#  'Leonard_Ochtman',
#  'Looperskapelle',
#  'Sirjansland',
#  'Staatkundig_Gereformeerde_Partij',
#  'Delta_Works',
#  'Zeeland',
#  'Zeeland_Bridge',
#  'Zierikzee',
#  'Zonnemaire',
#  'Category:Islands_of_Zeeland',
#  'John_III,_Lord_of_Renesse',
#  'Camille_Jordan',
#  'Carlos_Ghosn',
#  'Caroline_Aigle',
#  'Robert_Nivelle',
#  'Roger_Béteille',
#  'Roger_Guesnerie',
#  'Rose_Dieng-Kuntz',
#  'Menachem_Mendel_Schneerson',
#  'Benoît_Mandelbrot',
#  'Bernard_Arnault',
#  'Bertrand_Meyer',
#  'Denis_Ranque',
#  'Alfred_Potier',
#  'Joseph_Joffre',
#  'Joseph_Liouville',
#  'Jules_Brunet',
#  'Patrick_Drahi',
#  'Patrick_Kron',
#  'Patrick_Ky',
#  'Paul_Bert',
#  'Paul_Hermelin',
#  'Paul_Lévy_(mathematician)',
#  'Urbain_Le_Verrier',
#  "Valéry_Giscard_d'Estaing",
#  'Jacques_Rueff',
#  'Maurice_Allais',
#  'Louis_Pouzin',
#  'Louis_Vicat',
#  'Pierre_Henri_Hugoniot',
#  'Louis-Emile_Bertin',
#  'Christophe_Breuil',
#  'Claude-Louis_Navier',
#  'Claude_Burdin',
#  'Claude_Bébéar',
#  'Alexis_Bonnet',
#  'Alexis_Thérèse_Petit',
#  'Emile-René_Lemonnier',
#  'Emmanuel_Candès',
#  'François_Arago',
#  'Frédéric_Oudéa',
#  'Fulgence_Bienvenüe',
#  'Gabriel_Lamé',
#  'Georges_Besse',
#  'Georges_Charpy',
#  'Thierry_Desmarest',
#  'André-Louis_Cholesky',
#  'André_Citroën',
#  'Anne-Marie_Lagrange',
#  'Bernard_Salanié',
#  'Louis_Leprince-Ringuet',
#  'Louis_Pailhas',
#  'Léon_Charles_Thévenin',
#  'Siméon_Denis_Poisson',
#  'Stéphane_Mallat',
#  'Yves_Bréchet',
#  'Yves_Lambert',
#  'Édouard_Brézin',
#  'Émile_Clapeyron',
#  'Émile_Dorand',
#  'Émile_Lemoine',
#  'Étienne-Louis_Malus',
#  'François_Hussenot',
#  "Henri_Honoré_d'Estienne_d'Orves",
#  'Roger_Balian',
#  'Marc_Chervel',
#  'Marc_Fleury',
#  'Auguste_Bravais',
#  'Auguste_Comte',
#  'Bruno_Mégret',
#  'Agénor_Azéma_de_Montgravier',
#  'Tidjane_Thiam',
#  'Driss_Benhima',
#  'Abdourahmane_Cissé',
#  'Adhémar_Jean_Claude_Barré_de_Saint-Venant',
#  'Albert_Caquot',
#  'Albert_Jacquard',
#  'Albert_Lebrun',
#  'Alfred-Marie_Liénard',
#  'Alfred_Dreyfus',
#  'Ambroise_Roux',
#  'Edmond_Malinvaud',
#  'Eugène_Freyssinet',
#  'Fabienne_Keller',
#  'Ferdinand_Foch',
#  'Francis_Mer',
#  'Nicolas_Léonard_Sadi_Carnot',
#  'Farid_Zizi',
#  'Guy_du_Merle',
#  'Gérard_Berry',
#  'Gérard_Mestrallet',
#  'Gérard_Rozenknop',
#  'Henri-Alexandre_Deslandres',
#  'Henri_Becquerel',
#  'Henri_Brocard',
#  'Henri_Poincaré',
#  'Henri_Victor_Regnault',
#  'Henry_Darcy',
#  'Irénée-Jules_Bienaymé',
#  'Jacques_Attali',
#  'Jacques_Babinet',
#  'Calcium-48',
#  'California',
#  'Californium(III)_bromide',
#  'Californium(III)_chloride',
#  'Californium(III)_oxychloride',
#  'Californium(III)_polyborate',
#  'Americium',
#  'Category:Synthetic_elements',
#  "Przybylski's_Star",
#  'Neutron_activation_analysis',
#  'Nitrogen',
#  'Metallocene',
#  'Transuranium_element',
#  'Berkeley,_California',
#  'Beryllium',
#  'Beta_decay',
#  'Boron',
#  'Brain_tumor',
#  'Alloy',
#  'Antiferromagnetism',
#  'Aqueous_solution',
#  'Hydrogen',
#  'Hydroxide',
#  'Joint_Institute_for_Nuclear_Research',
#  'Perchlorate',
#  'Research_Institute_of_Atomic_Reactors',
#  'Cubic_crystal_system',
#  'Unit_cell',
#  'United_States_Department_of_Energy',
#  'University_of_California,_Berkeley',
#  'Uranium-238',
#  'Eastern_Idaho',
#  'Mass_number',
#  'Particle_accelerator',
#  'United_States_Atomic_Energy_Commission',
#  'Paramagnetism',
#  'Startup_neutron_source',
#  'Timeline_of_chemical_element_discoveries',
#  'Materials_Testing_Reactor',
#  'Melting_point',
#  'Russia',
#  'Chemical_element',
#  'Chemical_symbol',
#  'Naked_eye',
#  'Nuclear_reactor',
#  'Close-packing_of_equal_spheres',
#  'Electron_shell',
#  'Energy_Reorganization_Act_of_1974',
#  'Free_neutron',
#  'Gadolinium',
#  'Gamma_ray',
#  'Georgia_Tech',
#  'Glenn_T._Seaborg',
#  'Corrosion',
#  'Critical_mass',
#  'Crystal_structure',
#  'The_Periodic_Table_of_Videos',
#  'Orthorhombic_crystal_system',
#  '1958_US–UK_Mutual_Defence_Agreement',
#  'Berkelium',
#  'Boiling_point',
#  'Californium_compounds',
#  'Category:Californium',
#  'Category:Neutron_sources',
#  'Standard_atmosphere_(unit)',
#  'Synthetic_element',
#  'Actinide',
#  'Category:Actinides',
#  'Category:Chemical_elements',
#  'Cervical_cancer',
#  'U.S._state',
#  'Ion',
#  'Ion_exchange',
#  'Lanthanide',
#  'Lawrencium',
#  'Mineral_acid',
#  'Albert_Ghiorso',
#  'Alpha_particle',
#  'Curium',
#  'Cyclotron',
#  'Dubna',
#  'Dysprosium',
#  'Alpha_decay',
#  'Europium',
#  'Fermium',
#  'Fluoride',
#  'Nitrate',
#  'Nuclear_Regulatory_Commission',
#  'Nuclear_fallout',
#  'Nuclear_fission',
#  'Nuclear_weapons_testing',
#  'Oxalate',
#  'Oxidation_state',
#  'Pascal_(unit)',
#  'Isotope',
#  'Isotopes_of_americium',
#  'Isotopes_of_berkelium',
#  'Isotopes_of_californium',
#  'Isotopes_of_curium',
#  'Isotopes_of_nickel',
#  'Marie_Curie',
#  'Pierre',
#  'Marie_Curie',
#  'Calcium-48',
#  'California',
#  'Californium(III)_bromide',
#  'Californium(III)_chloride',
#  'Californium(III)_oxychloride',
#  'Californium(III)_polyborate',
#  'Americium',
#  'Category:Synthetic_elements',
#  "Przybylski's_Star",
#  'Neutron_activation_analysis',
#  'Nitrogen',
#  'Metallocene',
#  'Transuranium_element',
#  'Berkeley,_California',
#  'Beryllium',
#  'Beta_decay',
#  'Boron',
#  'Brain_tumor',
#  'Alloy',
#  'Antiferromagnetism',
#  'Aqueous_solution',
#  'Hydrogen',
#  'Hydroxide',
#  'Joint_Institute_for_Nuclear_Research',
#  'Perchlorate',
#  'Research_Institute_of_Atomic_Reactors',
#  'Cubic_crystal_system',
#  'Unit_cell',
#  'United_States_Department_of_Energy',
#  'University_of_California,_Berkeley',
#  'Uranium-238',
#  'Eastern_Idaho',
#  'Mass_number',
#  'Particle_accelerator',
#  'United_States_Atomic_Energy_Commission',
#  'Paramagnetism',
#  'Startup_neutron_source',
#  'Timeline_of_chemical_element_discoveries',
#  'Materials_Testing_Reactor',
#  'Melting_point',
#  'Russia',
#  'Chemical_element',
#  'Chemical_symbol',
#  'Naked_eye',
#  'Nuclear_reactor',
#  'Close-packing_of_equal_spheres',
#  'Electron_shell',
#  'Energy_Reorganization_Act_of_1974',
#  'Free_neutron',
#  'Gadolinium',
#  'Gamma_ray',
#  'Georgia_Tech',
#  'Glenn_T._Seaborg',
#  'Corrosion',
#  'Critical_mass',
#  'Crystal_structure',
#  'The_Periodic_Table_of_Videos',
#  'Orthorhombic_crystal_system',
#  '1958_US–UK_Mutual_Defence_Agreement',
#  'Berkelium',
#  'Boiling_point',
#  'Californium_compounds',
#  'Category:Californium',
#  'Category:Neutron_sources',
#  'Standard_atmosphere_(unit)',
#  'Synthetic_element',
#  'Actinide',
#  'Category:Actinides',
#  'Category:Chemical_elements',
#  'Cervical_cancer',
#  'U.S._state',
#  'Ion',
#  'Ion_exchange',
#  'Lanthanide',
#  'Lawrencium',
#  'Mineral_acid',
#  'Albert_Ghiorso',
#  'Alpha_particle',
#  'Curium',
#  'Cyclotron',
#  'Dubna',
#  'Dysprosium',
#  'Alpha_decay',
#  'Europium',
#  'Fermium',
#  'Fluoride',
#  'Nitrate',
#  'Nuclear_Regulatory_Commission',
#  'Nuclear_fallout',
#  'Nuclear_fission',
#  'Nuclear_weapons_testing',
#  'Oxalate',
#  'Oxidation_state',
#  'Pascal_(unit)',
#  'Isotope',
#  'Isotopes_of_americium',
#  'Isotopes_of_berkelium',
#  'Cartesian_coordinates',
#  'Potential_flow',
#  'Pressure',
#  'Boundary_condition',
#  'Joukowsky_transform',
#  "D'Alembert's_paradox",
#  'Vorticity',
#  'Del_in_cylindrical_and_spherical_coordinates',
#  'Kutta_condition',
#  'Mathematics',
#  'Boundary_layer',
#  'Density',
#  'Speed_of_sound',
#  'Drag_(physics)',
#  'Dynamic_pressure',
#  'Partial_differential_equation',
#  'Centripetal_acceleration',
#  'Radius',
#  'Category:Fluid_dynamics',
#  "Laplace's_equation",
#  'Polar_coordinates',
#  'Milton_Van_Dyke',
#  'Unit_vector',
#  'Mach_number',
#  'Magnus_effect',
#  'Wake_(physics)',
#  'Incompressible',
#  'Stream_function',
#  'Velocity_potential',
#  'Inviscid',
#  'Vector_identities',
#  'Fluid_flow',
#  'Velocity_field',
#  'Viscous_flow',
#  'Lord_Rayleigh',
#  'Modified_Bessel_function_of_the_first_kind',
#  'Boundary_layer_separation',
#  'Irrotational_flow',
#  'Surface_normal',
#  'File:CylinderStreamfunctionPotential.png',
#  'File:CylinderVelocityPressure.png',
#  'File:CylinderVelocityPressureQuadrant.png',
#  'File:Inviscid_flow_around_a_cylinder.gif',
#  'Candela',
#  'Category:Grade_II_listed_lighthouses',
#  'Bishop_Rock',
#  'Category:Sites_of_Special_Scientific_Interest_in_the_Isles_of_Scilly',
#  'Category:Uninhabited_islands_of_the_Isles_of_Scilly',
#  'Hydrobates_pelagicus',
#  'Listed_building',
#  'Listed_buildings_in_Tresco,_Isles_of_Scilly',
#  'Sea_beet',
#  'Spergularia',
#  'Watt_steam_engine',
#  'Commissioners_of_Irish_Lights',
#  'Category:Lighthouses_completed_in_1887',
#  'Mechanical_traveller',
#  'Radio_beacon',
#  'England',
#  'Morse_code',
#  'Antenna_(radio)',
#  'Armeria_maritima',
#  'Lotus_corniculatus',
#  'Cairn',
#  'Hornsby-Akroyd_oil_engine',
#  'Lesser_white-toothed_shrew',
#  'Bronze_Age_Britain',
#  'Trinity_House',
#  'William_Douglass_(engineer)',
#  'Disphyma_crassifolium',
#  'Hathorn_Davey',
#  'Rodenticide',
#  'Category:Sites_of_Special_Scientific_Interest_notified_in_1995',
#  'Granite',
#  'Isles_of_Scilly',
#  'Isles_of_Scilly_Wildlife_Trust',
#  'Hyperradiant_Fresnel_lens',
#  'Atlantic_puffin',
#  'Atriplex',
#  'Job_Edward_Lousley',
#  'Kilometres_per_hour',
#  'Bishop_Rock_Lighthouse',
#  'Category:Lighthouses_in_the_Isles_of_Scilly',
#  'Hoist_(device)',
#  'Ashlar',
#  'Asplenium_marinum',
#  'Manx_shearwater',
#  'Marconi_Company',
#  'St_Agnes,_Isles_of_Scilly',
#  'Focal_plane',
#  'Carpobrotus_edulis',
#  'Chance_Brothers',
#  'Miles_per_hour',
#  'Site_of_Special_Scientific_Interest',
#  'Lavatera_arborea',
#  'List_of_shipwrecks_of_the_Isles_of_Scilly',
#  'Hercynian',
#  'Sealed_beam',
#  'Rattus_norvegicus',
#  'Photovoltaic_cells',
#  'Carl_Severing',
#  'Preußenschlag',
#  'Enabling_Act_of_1933',
#  'Bolsheviks',
#  'July_1932_German_federal_election',
#  "People's_State_of_Hesse",
#  'Reichsbanner_Schwarz-Rot-Gold',
#  'Reichstag_(Weimar_Republic)',
#  'Reichstag_Fire_Decree',
#  '1928_German_federal_election',
#  '1930_German_federal_election',
#  '1932_Prussian_state_election',
#  'Max_Weber',
#  'Mierendorffplatz',
#  'Wandervogel',
#  'Freiburg',
#  'German_Empire',
#  'German_Revolution_of_1918–1919',
#  'Munich',
#  'Antisemitism',
#  'Leipzig',
#  'Ludwig_Beck',
#  'Lutheran',
#  'Social_Democratic_Party_of_Germany',
#  'Łódź',
#  'Kreisau_Circle',
#  'Category:1897_births',
#  'Category:1943_deaths',
#  'Category:Deaths_by_airstrike_during_World_War_II',
#  'Category:German_Army_personnel_of_World_War_I',
#  'Category:German_civilians_killed_in_World_War_II',
#  'Category:German_resistance_members',
#  'Category:Members_of_the_Reichstag_of_the_Weimar_Republic',
#  'Category:Social_Democratic_Party_of_Germany_politicians',
#  'Walther_Rathenau',
#  'Weimar_Republic',
#  'Iron_Cross',
#  'Albert_Einstein',
#  'Darmstadt',
#  'First_World_War',
#  'November_1932_German_federal_election',
#  'Osthofen_concentration_camp',
#  'Otto_Braun',
#  'Proportional_representation',
#  'Raised_fist',
#  'Großenhain',
#  'Heidelberg',
#  'Hesse',
#  'Iron_Front',
#  'Category:People_from_the_Kingdom_of_Saxony',
#  'Category:Nazi_concentration_camp_survivors',
#  'Charlottenburg',
#  'March_1933_German_federal_election',
#  'Philipp_Lenard',
#  'Social_democracy',
#  'Kingdom_of_Saxony',
#  'Nazi_Germany',
#  'Nazi_Party',
#  'Sergei_Chakhotin',
#  'Wilhelm_Leuschner',
#  'Three_Arrows',
#  'Humanist',
#  'Party_list',
#  'Vorwärts',
#  'Wilhelm_II',
#  'Nazi_rise_to_power',
#  'Völkisch',
#  'Expropriation_of_the_princes',
#  'File:Three_Arrows_election_poster_of_the_Social_Democratic_Party_of_Germany,_1932_-_Gegen_Papen,_Hitler,_Thälmann.png',
#  'Canan_Bayram',
#  'Carl_Adam_Petri',
#  'Carl_Remigius_Fresenius',
#  'Carl_Schmitt',
#  'Carl_Schurz',
#  'Carl_Troll',
#  'Carrie_Derick',
#  'Benedict_Welte',
#  'Benedikt_Niese',
#  'Pradyut_Ghosh',
#  'Prince_Christian_of_Schleswig-Holstein',
#  'Prince_Friedrich_Karl_of_Prussia_(1828–1885)',
#  'Prince_Wilhelm_of_Prussia_(1906–1940)',
#  'Prosper_de_Haulleville',
#  'Robert_Schuman',
#  'Robert_Skeris',
#  'Robert_Whytlaw-Gray',
#  'Robert_Wintgen',
#  'Ronald_Crutcher',
#  'Ronald_Jensen',
#  'Ronald_Smelser',
#  'Rudolf_Lipschitz',
#  'Rudolf_Scharping',
#  'Samuel_Adler_(rabbi)',
#  'Sandra_Bartky',
#  'Paul_Moldenhauer',
#  'Wolfgang_Menzel',
#  'Léonard_Willems',
#  'Mehmet_Celal_Bey',
#  'Nobel_Prize_in_Chemistry',
#  'Walter_Weizel',
#  'Cambridge_University_Library',
#  'Cambridge_University_Press',
#  'Roger_Penrose',
#  'Scientific_journal',
#  'Nobel_Prize_in_Chemistry',
#  'John_Stevens_Henslow',
#  'John_William_Strutt,_3rd_Baron_Rayleigh',
#  'Joseph_Larmor',
#  'Paul_Dirac',
#  'University_of_Cambridge',
#  'Category:Clubs_and_societies_of_the_University_of_Cambridge',
#  'On_the_Origin_of_Species',
#  "Christ's_College,_Cambridge",
#  'Edward_Daniel_Clarke',
#  'Geological_Society_of_London',
#  'Antony_Hewish',
#  'Category:Philosophical_societies_in_the_United_Kingdom',
#  'Cambridge_University_Moral_Sciences_Club',
#  'Category:Organizations_established_in_1819',
#  'Stephen_Hawking',
#  'Fellow',
#  'Mathematical_Proceedings_of_the_Cambridge_Philosophical_Society',
#  'Adam_Sedgwick',
#  'Alan_Turing',
#  'Category:Scientific_societies_based_in_the_United_Kingdom',
#  'Ernest_Rutherford',
#  'Francis_Crick',
#  'Nobel_Prize',
#  'Nobel_Prize_in_Physics',
#  'HMS_Beagle',
#  'Hendrik_Lorentz',
#  'J._J._Thomson',
#  'James_Francis_Stephens',
#  'Category:1819_establishments_in_England',
#  'Charles_Babbage',
#  'Charles_Darwin',
#  'King_William_IV',
#  'Law',
#  'Lawrence_Bragg',
#  'Dorothy_Hodgkin',
#  'Marie_Curie',
#  'Martin_Rees',
#  'Philosophy',
#  'Pieter_Zeeman',
#  'Second_voyage_of_HMS_Beagle',
#  'Medicine',
#  'Extracts_from_Letters_to_Henslow',
#  'Theology',
#  'File:Stephen_Hawking.StarChild.jpg',
#  'File:Cambridge-philosophical-society-blue-plaque.jpg',
#  'File:Extracts_from_letters_to_Henslow.jpeg',
#  'File:On-the-fishes-of-madeira.jpg',
#  'Cambridge',
#  'Cambridge_Zero',
#  'Category:Cambridge_University_Press',
#  'Pound_sterling',
#  'Robert_Solow',
#  'Samuel_Beckett',
#  'Monograph',
#  'Monotyping',
#  'Privileged_presses',
#  'Bertrand_Russell',
#  'Book_of_Common_Prayer',
#  'Dennis_Gabor',
#  'Derek_Barton',
#  'Alms_for_Jihad',
#  'Joseph_Stiglitz',
#  'Listed_building',
#  'Patrick_Blackett',
#  'Perlego',
#  'Peter_Diamond',
#  'Richard_Feynman',
#  'Richard_Stone',
#  'Robert_Fogel',
#  'United_States_House_of_Representatives',
#  'University_of_Cambridge',
#  'University_of_Cambridge_Local_Examinations_Syndicate',
#  'Vernon_L._Smith',
#  'David_Kindersley',
#  'Independent_Publishers_Guild',
#  'Ingram_Content_Group',
#  'Letters_patent',
#  'World_Book_Day',
#  'Country',
#  'Max_Born',
#  'Max_Perutz',
#  'SAP',
#  'Christopher_A._Pissarides',
#  'Christopher_A._Sims',
#  'Claude_Cohen-Tannoudji',
#  'Clive_Granger',
#  'Coleridge_Community_College',
#  'Edward_Blore',
#  'Elinor_Ostrom',
#  'Franco_Modigliani',
#  'Frank_Wolf_(politician)',
#  'George_Akerlof',
#  'George_Herbert',
#  'Georgia_State_University',
#  "Gerard_'t_Hooft",
#  'Cardiopulmonary_resuscitation',
#  'Case_School_of_Dental_Medicine',
#  'Case_Western_Reserve_Spartans_football',
#  'Case_Western_Reserve_University_School_of_Law',
#  'Case_Western_Reserve_University_School_of_Medicine',
#  'American_Anti-Slavery_Society',
#  'American_lower_class',
#  'American_middle_class',
#  'Category:Technological_universities_in_the_United_States',
#  'Bed',
#  "Presidents'_Athletic_Conference",
#  'Psychology',
#  'Robert_W._Morse',
#  'Samuel_Mather',
#  'Scott_Cowen',
#  'Electrochemical_engineering',
#  'Electrochemistry',
#  'MIDI',
#  'Michelson–Morley_experiment',
#  'National_Association_for_College_Admission_Counseling',
#  'M._Frank_Rudy',
#  'Nobel_Prize_in_Chemistry',
#  'UNIVAC_1107',
#  'Beachwood,_Ohio',
#  'Beta_Theta_Pi',
#  'Beta_decay',
#  'Biology',
#  'Biomedical_Engineering',
#  'Blood_transfusion',
#  'David_H._Auston',
#  'David_Hudson_(pioneer)',
#  'David_V._Ragone',
#  'Dayton_Miller',
#  'Delta_Chi',
#  'Delta_Gamma',
#  'Delta_Sigma_Phi',
#  'Delta_Tau_Delta',
#  'Delta_Upsilon',
#  'Allostasis',
#  'Category:Private_universities_and_colleges_in_Ohio',
#  'Hollywood_(film_industry)',
#  'Houston',
#  'Hudson,_Ohio',
#  'Hunting_Valley,_Ohio',
#  'John_S._Millis',
#  'John_Sykes_Fayette',
#  'Biba_Model',
#  'Little_Italy–University_Circle_station',
#  'Paul_Berg',
#  'Paul_Buchheit',
#  'Peter_Agre',
#  'Peter_Sterling_(Neuroscientist)',
#  'Peter_Tippett',
#  'Research_and_development',
#  'Richard_Thaler',
#  'Risk_assessment',
#  'Riyadh',
#  'Robert_Kearns',
#  'Underground_Railroad',
#  'Universities_Research_Association',
#  'University_Athletic_Association',
#  'University_Circle',
#  'University_of_Minnesota',
#  'Defibrillation',
#  'Dormitory',
#  'Downtown_Cleveland',
#  'Infant_formula',
#  'Information_asymmetry',
#  'Internet',
#  'Internet_Streaming_Media_Alliance',
#  'LDS-1_(Line_Drawing_System-1)',
#  'Luminiferous_aether',
#  'Pay-by-phone_parking',
#  'Pell_grant',
#  'Corneille_Heymans',
#  'Cosmic_ray',
#  'Craig_Newmark',
#  'Craigslist',
#  'Mechanical_Engineering',
#  'STS-50',
#  'STS-73',
#  'Nursing',
#  'Simon_Ostrach',
#  'Whegs',
#  'Particle_detector',
#  'Civil_rights_movement',
#  'Claude_Beck',
#  'Cleveland',
#  'Cleveland_Botanical_Garden',
#  'Cleveland_Clinic',
#  'Cleveland_Institute_of_Music',
#  'Cleveland_Museum_of_Art',
#  'Cleveland_Museum_of_Natural_History',
#  'Cleveland_Orchestra',
#  'Edward_C._Prescott',
#  'Edward_M._Hundert',
#  'Edward_W._Morley',
#  'Edward_Williams_(businessman)',
#  'Elias_Loomis',
#  'Elizur_Wright',
#  ...]

# %%
# Split Data into train_test_split and run KMeans clustering on the objects with 2 clusters
X_train, X_test = train_test_split(objects, test_size=0.2, random_state=42)

vectorizer = TfidfVectorizer()
X_train_vectorized = vectorizer.fit_transform(X_train)
X_test_vectorized = vectorizer.transform(X_test)

kmeans = KMeans(n_clusters=2, random_state=42)
kmeans.fit(X_train_vectorized)

# Predict the clusters for the test data
predicted_clusters = kmeans.predict(X_test_vectorized)

# Get the cluster centers
cluster_centers = kmeans.cluster_centers_

# Reduce the dimensionality of the cluster centers to 2D
pca = PCA(n_components=2)
cluster_centers_2d = pca.fit_transform(cluster_centers)

# Reduce the dimensionality of the test data to 2D
X_test_vectorized_2d = pca.transform(X_test_vectorized)

# Plot the clusters
plt.scatter(X_test_vectorized_2d[:, 0], X_test_vectorized_2d[:, 1], c=predicted_clusters)
plt.scatter(cluster_centers_2d[:, 0], cluster_centers_2d[:, 1], c='red', marker='x')
plt.title("KMeans Clustering of Nobel Laureate Knowledge Graph Objects")
plt.show()
